# %%
# %run djscript.py

# %%
# %matplotlib inline

# %%
matplotlib.rcParams['figure.figsize'] = (20.0, 10.0)

# %% [markdown]
# <font color=red>Text</font>

# %%
desc = X1.describe()
desc

# %%
Y1= pd.DataFrame.dropna(Y1,axis=0)
Y1diff = np.diff(Y1,axis=1)

# %%
Y1diff = pd.DataFrame(Y1diff)
Y1diff.plot(figsize=(16,10))

# %% [markdown]
# # Don't you love plots?
# Here is mx Orange

# %%
for column in Y1.drop('p1', axis=1):
    plt.plot(Y1, marker='', color='grey', linewidth=1, alpha=0.4)
plt.plot(Y1['p1'], marker='', color='orange', linewidth=4, alpha=0.7)
plt.xlabel('Mx Orange')
plt.ylabel('ACC in Y')
plt.title('Mx Orange vs the world')
# Out:
# Text(0.5,1,u'Mx Orange vs the world')

# %%
X1.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9fbfce0e10>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9fbfa38f90>]], dtype=object)

# %%
f,ax = plt.subplots(figsize=(16,10))
X1.boxplot()

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(X1, alpha=0.2, figsize=(16, 16), diagonal='kde')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9fbe6965d0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9fbd982290>]], dtype=object)

# %%
emgdesc1 = EMG1.describe()

# %%
import seaborn as sns
sns.set_style("whitegrid")             

paper_rc = {'lines.linewidth': 1, 'lines.markersize': 10}     
fig,ax =plt.subplots(figsize=(16, 10))
ax = sns.violinplot(x=emgdesc1['p1'],y=emgdesc1['p2'],
                     split = True,inner="stick",scale="count",bw=.3,palette="RdBu", color_codes=True)
plt.xlabel('Mel',fontsize='32')
plt.ylabel('qom',fontsize = '28')
plt.setp(ax.get_legend().get_texts(), fontsize='28') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='2') # for legend title
# Out:
# ----------------------------------------------
# AttributeErrorTraceback (most recent call last)
# <ipython-input-87-872a3f1ca18d> in <module>()
#       8 plt.xlabel('Mel',fontsize='32')
#       9 plt.ylabel('qom',fontsize = '28')
# ---> 10 plt.setp(ax.get_legend().get_texts(), fontsize='28') # for legend text
#      11 plt.setp(ax.get_legend().get_title(), fontsize='2') # for legend title
#
# AttributeError: 'NoneType' object has no attribute 'get_texts'

# %%
EMG1.plot()

# %%
x = 
def animate(i):
    line.set_ydata(np.sin(x + i/10.0))  # update the data
    return line,
def init():
    line.set_ydata(np.ma.array(x, mask=True))
    return line,
ani = animation.FuncAnimation(fig, animate, np.arange(1, 200), init_func=init,
                              interval=25, blit=True)
plt.show()

# %%
f,a = plt.subplots(figsize = (16,10))
for i in range(len(X1.keys())):
    a = plt.plot(X1.iloc[:,i])

# %%
'''Self corr for Acc X'''

import numpy as np

# Compute the correlation matrix
corr = X1.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df1.corr()
# Out:
#                                        Trigno sensor 1: EMG 1 [Volts]  \
# Trigno sensor 1: EMG 1 [Volts]                               1.000000
# X [s].1                                                     -0.001088
# Trigno sensor 1: ACC X 1 [g]                                -0.008085
# X [s].2                                                     -0.001088
# Trigno sensor 1: ACC Y 1 [g]                                 0.001902
# X [s].3                                                     -0.001088
# Trigno sensor 1: ACC Z 1 [g]                                -0.004000
# X [s].4                                                      0.000428
# Trigno sensor 2: EMG 2 [Volts]                              -0.000225
# X [s].5                                                     -0.001088
# Trigno sensor 2: ACC X 2 [g]                                -0.002580
# X [s].6                                                     -0.001088
# ...

# %%
df1.describe()
# Out:
#        Trigno sensor 1: EMG 1 [Volts]       X [s].1  \
# count                    2.318420e+05  17834.000000
# mean                    -8.241164e-07     60.186415
# std                      1.729252e-05     34.751570
# min                     -3.380480e-04      0.000000
# 25%                     -5.706870e-06     30.093200
# 50%                     -5.035480e-07     60.186400
# 75%                      4.531930e-06     90.279600
# max                      4.986800e-04    120.373000
#
#        Trigno sensor 1: ACC X 1 [g]       X [s].2  \
# count                  17834.000000  17834.000000
# mean                      -0.730139     60.186415
# std                        0.178343     34.751570
# min                       -1.498560      0.000000
# 25%                       -0.858045     30.093200
# 50%                       -0.781506     60.186400
# 75%                       -0.656626     90.279600
# max                        0.153078    120.373000
#
# ...
